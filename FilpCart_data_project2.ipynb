# %%
from datetime import datetime
class Flipcart:
    ####commen info add in this 
    ##access by class name and value
    def User(self,id,name,Mob,email):
        self.id=ID   #instance each user has differnt infok
        self.name=Name   ##in obj atribute and class attribute always obj attribute give high priority
        self.Mob=Mobile
        self.email = email
   
    def Register(self):
        name = input("Enter Name: ")
        email = input("Enter Email: ")
        password = input("Enter Password: ")

        if name.isalpha():
            self.name = name
            self.email = email
            self.password = password
            print("Registration Successful!")
        else:
            print("Invalid Name")   
    
    def Login(self):
        email = input("Enter Email: ")
        password = input("Enter Password: ")

        if email == self.email and password == self.password:
            print("Login Successfully! Go to Home Page")
        else:
            print("Wrong Email or Password")
        
    
class Product:
    def __init__(self):
            self.products = {
            1: {"name": "Shirt", "price": 1000},
            2: {"name": "Shoes", "price": 2000},
            3: {"name": "T-Shirt", "price": 800},
            4: {"name": "Kurti", "price": 1200}
        }
        
    def show_products(self):
        for pid, details in self.products.items():
            print(pid, details["name"], "Price:", details["price"])

    def select_product(self,pid):
        # self.show_products()
        # pid=int(input("Enter the Product ID:"))
        if pid in self.products:
            return self.products[pid]
        else:
            return "Product Not Available"
    
class Category:

    def __init__(self):
        self.items = {
            1: "Electronics",
            2: "Fashion",
            3: "Home",
            4: "Books",
            5: "Grocery"
        }

    def show_category(self):
        for id, name in self.items.items():
            print(id, name)



class Order:

    def __init__(self, order_id, amount):
        self.order_id = order_id
        self.date = datetime.now()
        self.total_amount = amount
        self.status = "Placed"

    def order_status(self):
        print("Order Status:", self.status)

    def change_order_status(self, new_status):
        self.status = new_status
        print("Order Status Updated to:", self.status)


class Review:

    def __init__(self, product, rating):
        self.product = product
        self.rating = rating

    def add_review(self):
        print("Review Added for", self.product)
        print("Rating:", self.rating)

E=Flipcart()
E.Register()
E.Login()

P=Product()
P.show_products()
P.select_product(2)

C=Category()
C.show_category()

O=Order(1,100)
O.order_status()
O.change_order_status("Shipped")

R=Review("Shirt",2)
R.add_review()
# Out:
# Enter Name:  biljk
# Enter Email:  okj
# Enter Password:  8
# Registration Successful!
# Enter Email:  oijkpo
# Enter Password:   ol
# Wrong Email or Password
# 1 Shirt Price: 1000
# 2 Shoes Price: 2000
# 3 T-Shirt Price: 800
# 4 Kurti Price: 1200
# 1 Electronics
# 2 Fashion
# 3 Home
# 4 Books
# 5 Grocery
# Order Status: Placed
# Order Status Updated to: Shipped
# Review Added for Shirt
# Rating: 2
